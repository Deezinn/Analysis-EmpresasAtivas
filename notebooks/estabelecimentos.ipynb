# %% [markdown]
# ## Trabalharemos com a análise de empresas ativas no Recife.

# %% [markdown]
# ### Importando:

# %%
import pandas as pd
import numpy as np

# %%
estabelecimentos = pd.read_csv('/home/deezinn/Documentos/Meus Projetos Pessoais/Analysis-EmpresasAtivas/data/ESTABELECIMENTOS.csv',
                             sep=',',
                             encoding='utf-8',
                             low_memory=False )

# %%
pd.set_option('display.max_columns', None)

# %%
estabelecimentos.head()
# Out:
#    CNPJ BASICO  CNPJ ORDEM  CNPJ DV MATRIZ/FILIAL  \
# 0     32630978           1       23        MATRIZ
# 1     32639324           1       60        MATRIZ
# 2     32646362           1       40        MATRIZ
# 3     30969073           1       57        MATRIZ
# 4     32756902           1       49        MATRIZ
#
#                      RAZAO SOCIAL / NOME EMPRESARIAL  \
# 0       CRISTIANNE LIMA DE OLIVEIRA REIS 50964364468
# 1  ACV CONSULTORIA E TREINAMENTO EM GESTAO PROFIS...
# 2                 JOSE CARLOS DE MENEZES 02742601406
# 3                  LUZIANA MARIA DE SANTANA OLIVEIRA
# 4            DANIELE FERREIRA DE SANTANA 09850269448
#
#                          NOME FANTASIA SITUAÇÃO CADASTRAL  \
# 0                                  NaN             INAPTA
# 1  AV CONSULTORIA EM SISTEMA DE GESTAO              ATIVA
# 2                                  NaN            BAIXADA
# 3                      LUZIANA IMOVEIS            BAIXADA
# ...

# %%
colunas_datetime = ['DATA DA SITUAÇÃO CADASTRAL', 'DATA DA SITUAÇÃO ESPECIAL', 'DATA DE INÍCIO DE ATIVIDADE']


for coluna in colunas_datetime:
    estabelecimentos[coluna] = pd.to_datetime(estabelecimentos[coluna], format='%Y%m%d', errors='coerce')

# %%
estabelecimentos.head(2)
# Out:
#    CNPJ BASICO  CNPJ ORDEM  CNPJ DV MATRIZ/FILIAL  \
# 0     32630978           1       23        MATRIZ
# 1     32639324           1       60        MATRIZ
# 2     32646362           1       40        MATRIZ
# 3     30969073           1       57        MATRIZ
# 4     32756902           1       49        MATRIZ
#
#                      RAZAO SOCIAL / NOME EMPRESARIAL  \
# 0       CRISTIANNE LIMA DE OLIVEIRA REIS 50964364468
# 1  ACV CONSULTORIA E TREINAMENTO EM GESTAO PROFIS...
# 2                 JOSE CARLOS DE MENEZES 02742601406
# 3                  LUZIANA MARIA DE SANTANA OLIVEIRA
# 4            DANIELE FERREIRA DE SANTANA 09850269448
#
#                          NOME FANTASIA SITUAÇÃO CADASTRAL  \
# 0                                  NaN             INAPTA
# 1  AV CONSULTORIA EM SISTEMA DE GESTAO              ATIVA
# 2                                  NaN            BAIXADA
# 3                      LUZIANA IMOVEIS            BAIXADA
# ...
